# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\Admin\Downloads\matches.csv-20231125T055512Z-001\matches.csv')

# %%
df_del=pd.read_csv(r'C:\Users\Admin\Downloads\deliveries.csv-20231125T055515Z-001\deliveries.csv')

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df['dl_applied'].value_counts()
# Out:
# 0    737
# 1     19
# Name: dl_applied, dtype: int64

# %%
df['id'].value_counts()
# Out:
# 1        1
# 509      1
# 500      1
# 501      1
# 502      1
#         ..
# 254      1
# 255      1
# 256      1
# 257      1
# 11415    1
# Name: id, Length: 756, dtype: int64

# %%
df=df.rename(columns={'id':'match_id'})

# %%
df.head()
# Out:
#    match_id  season       city        date                        team1  \
# 0         1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1         2    2017       Pune  2017-04-06               Mumbai Indians
# 2         3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3         4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4         5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df_del.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df_del['match_id'].value_counts()
# Out:
# 126      267
# 34       263
# 534      262
# 476      262
# 388      261
#         ...
# 120      108
# 568      106
# 452      100
# 301       63
# 11340     51
# Name: match_id, Length: 756, dtype: int64

# %%
final_df=pd.merge(df_del,df,on='match_id')

# %%
final_df.shape
# Out:
# (179078, 38)

# %%
final_df.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# season                   0
# city                  1700
# date                     0
# team1                    0
# team2                    0
# toss_winner              0
# toss_decision            0
# result                   0
# dl_applied               0
# winner                 372
# win_by_runs              0
# win_by_wickets           0
# player_of_match        372
# ...

# %%
final_df['city'].value_counts().sort_values(ascending=False)
# Out:
# Mumbai            24302
# Kolkata           17991
# Delhi             17305
# Hyderabad         15215
# Bangalore         15155
# Chennai           13895
# Jaipur            11158
# Chandigarh        10840
# Pune               9119
# Durban             3643
# Bengaluru          3248
# Visakhapatnam      3037
# Ahmedabad          2893
# Centurion          2866
# Mohali             2431
# Rajkot             2381
# Dharamsala         2159
# Indore             1965
# Johannesburg       1940
# Cuttack            1695
# Port Elizabeth     1677
# Ranchi             1671
# Abu Dhabi          1624
# Cape Town          1539
# Sharjah            1439
# Raipur             1431
# Kochi              1155
# Kanpur              921
# Nagpur              742
# Kimberley           726
# East London         715
# Bloemfontein        500
# Name: city, dtype: int64

# %%
final_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'season', 'city', 'date', 'team1', 'team2',
#        'toss_winner', 'toss_decision', 'result', 'dl_applied', 'winner',
#        'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue', 'umpire1',
#        'umpire2', 'umpire3'],
#       dtype='object')

# %%
final_df['date']=pd.to_datetime(df['date'])

# %%
import datetime as dt

# %%
final_df['date'].value_counts().sort_values(ascending=False)
# Out:
# 2011-04-17    2
# 2008-05-21    2
# 2008-05-25    2
# 2017-04-30    2
# 2009-04-26    2
#              ..
# 2016-05-06    1
# 2016-04-11    1
# 2016-04-13    1
# 2016-04-14    1
# 2019-12-05    1
# Name: date, Length: 546, dtype: int64

# %%
final_df['date'].sort_values(ascending=False)
# Out:
# 755      2019-12-05
# 721      2019-12-04
# 720      2019-11-04
# 754      2019-10-05
# 719      2019-10-04
#             ...
# 179073          NaT
# 179074          NaT
# 179075          NaT
# 179076          NaT
# 179077          NaT
# Name: date, Length: 179078, dtype: datetime64[ns]

# %%
final_df['year']=final_df['date'].dt.year

# %%
final_df['year'].value_counts()
# Out:
# 2013.0    76
# 2012.0    74
# 2011.0    73
# 2010.0    60
# 2014.0    60
# 2016.0    60
# 2018.0    60
# 2019.0    60
# 2017.0    59
# 2015.0    59
# 2008.0    58
# 2009.0    57
# Name: year, dtype: int64

# %%
final_df.head(2)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  dl_applied  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...           0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...           0
#
#                 winner  win_by_runs  win_by_wickets  player_of_match  \
# 0  Sunrisers Hyderabad           35               0     Yuvraj Singh
# 1  Sunrisers Hyderabad           35               0     Yuvraj Singh
#
#                                        venue      umpire1   umpire2 umpire3  \
# 0  Rajiv Gandhi International Stadium, Uppal  AY Dandekar  NJ Llong     NaN
# 1  Rajiv Gandhi International Stadium, Uppal  AY Dandekar  NJ Llong     NaN
#
#      year
# 0  2017.0
# 1  2017.0
#
# [2 rows x 39 columns]

# %%
final_df['winner'].value_counts()
# Out:
# Mumbai Indians                 26305
# Chennai Super Kings            24087
# Kolkata Knight Riders          21644
# Royal Challengers Bangalore    19553
# Kings XI Punjab                19469
# Rajasthan Royals               17948
# Delhi Daredevils               15709
# Sunrisers Hyderabad            13786
# Deccan Chargers                 7013
# Gujarat Lions                   3063
# Pune Warriors                   2883
# Delhi Capitals                  2436
# Rising Pune Supergiant          2383
# Kochi Tuskers Kerala            1322
# Rising Pune Supergiants         1105
# Name: winner, dtype: int64

# %%
final_df.groupby('year')['winner'].sum()
# Out:
# year
# 2008.0    Sunrisers HyderabadSunrisers HyderabadSunriser...
# 2009.0    Sunrisers HyderabadSunrisers HyderabadSunriser...
# 2010.0    Sunrisers HyderabadSunrisers HyderabadSunriser...
# 2011.0    Sunrisers HyderabadSunrisers HyderabadSunriser...
# 2012.0    Rising Pune SupergiantRising Pune SupergiantRi...
# 2013.0    Rising Pune SupergiantRising Pune SupergiantRi...
# 2014.0    Rising Pune SupergiantRising Pune SupergiantRi...
# 2015.0    Kolkata Knight RidersKolkata Knight RidersKolk...
# 2016.0    Kolkata Knight RidersKolkata Knight RidersKolk...
# 2017.0    Sunrisers HyderabadSunrisers HyderabadSunriser...
# 2018.0    Kolkata Knight RidersKolkata Knight RidersKolk...
# 2019.0    Kolkata Knight RidersKolkata Knight RidersKolk...
# Name: winner, dtype: object

# %%
final_df[(final_df['year']==2011.0)|(final_df['winner']=='Mumbai Indians')].head(20)
# Out:
#      match_id  inning                 batting_team            bowling_team  \
# 234         1       2  Royal Challengers Bangalore     Sunrisers Hyderabad
# 235         1       2  Royal Challengers Bangalore     Sunrisers Hyderabad
# 236         1       2  Royal Challengers Bangalore     Sunrisers Hyderabad
# 237         1       2  Royal Challengers Bangalore     Sunrisers Hyderabad
# 238         1       2  Royal Challengers Bangalore     Sunrisers Hyderabad
# 239         1       2  Royal Challengers Bangalore     Sunrisers Hyderabad
# 240         1       2  Royal Challengers Bangalore     Sunrisers Hyderabad
# 241         1       2  Royal Challengers Bangalore     Sunrisers Hyderabad
# 242         1       2  Royal Challengers Bangalore     Sunrisers Hyderabad
# 243         1       2  Royal Challengers Bangalore     Sunrisers Hyderabad
# 244         1       2  Royal Challengers Bangalore     Sunrisers Hyderabad
# ...

# %%
final_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'season', 'city', 'date', 'team1', 'team2',
#        'toss_winner', 'toss_decision', 'result', 'dl_applied', 'winner',
#        'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue', 'umpire1',
#        'umpire2', 'umpire3', 'year'],
#       dtype='object')

# %%
final_df['toss_decision'].value_counts().plot.pie(autopct="%.1f%%")
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
final_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'season', 'city', 'date', 'team1', 'team2',
#        'toss_winner', 'toss_decision', 'result', 'dl_applied', 'winner',
#        'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue', 'umpire1',
#        'umpire2', 'umpire3', 'year'],
#       dtype='object')

# %%
final_df['toss_decision'].value_counts()
# Out:
# field    109222
# bat       69856
# Name: toss_decision, dtype: int64

# %%
final_df.groupby(['year','toss_decision'])['winner'].count().sort_values(ascending=False)
# Out:
# year    toss_decision
# 2013.0  field            76
# 2012.0  field            74
# 2011.0  field            73
# 2010.0  field            60
# 2014.0  field            60
# 2016.0  field            60
# 2018.0  field            60
# 2019.0  field            60
# 2015.0  field            59
# 2017.0  field            59
# 2008.0  field            58
# 2009.0  field            57
# Name: winner, dtype: int64

# %%
final_df.groupby('batsman')['total_runs'].sum().sort_values(ascending=False)/sum(final_df['ball'])*100
# Out:
# batsman
# SK Raina          0.872779
# V Kohli           0.867373
# RG Sharma         0.781038
# DA Warner         0.768373
# S Dhawan          0.753083
#                     ...
# J Denly           0.000000
# V Pratap Singh    0.000000
# Abdur Razzak      0.000000
# Sunny Gupta       0.000000
# ND Doshi          0.000000
# Name: total_runs, Length: 516, dtype: float64

# %%
final_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'season', 'city', 'date', 'team1', 'team2',
#        'toss_winner', 'toss_decision', 'result', 'dl_applied', 'winner',
#        'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue', 'umpire1',
#        'umpire2', 'umpire3', 'year'],
#       dtype='object')

# %%
df1=final_df.groupby('bowler')['wide_runs','bye_runs','legbye_runs','noball_runs','penalty_runs'].sum().reset_index()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1064\4172698742.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1=final_df.groupby('bowler')['wide_runs','bye_runs','legbye_runs','noball_runs','penalty_runs'].sum().reset_index()

# %%
df1.sort_values(['wide_runs'])
# Out:
#           bowler  wide_runs  bye_runs  legbye_runs  noball_runs  penalty_runs
# 357  Sachin Baby          0         0            0            0             0
# 77      CJ McKay          0         0            0            0             0
# 220     MG Neser          0         0            0            1             0
# 273      R Ninan          0         0            0            0             0
# 274      R Parag          0         0            0            0             0
# ..           ...        ...       ...          ...          ...           ...
# 381     UT Yadav        110        16           74           19             0
# 269     R Ashwin        111         9           45            2             0
# 93      DJ Bravo        124         3           68            6             0
# 251      P Kumar        144         5           86            1             0
# 340   SL Malinga        152        28           88           20             5
#
# [405 rows x 6 columns]

# %%
final_df['venue'].value_counts().sort_values(ascending=False)
# Out:
# Eden Gardens                                            17991
# Wankhede Stadium                                        17590
# M Chinnaswamy Stadium                                   16872
# Feroz Shah Kotla                                        15604
# Rajiv Gandhi International Stadium, Uppal               13303
# MA Chidambaram Stadium, Chepauk                         12006
# Sawai Mansingh Stadium                                  11158
# Punjab Cricket Association Stadium, Mohali               8266
# Maharashtra Cricket Association Stadium                  5055
# Subrata Roy Sahara Stadium                               4064
# Dr DY Patil Sports Academy                               3993
# Kingsmead                                                3643
# Punjab Cricket Association IS Bindra Stadium, Mohali     3315
# Sardar Patel Stadium, Motera                             2893
# SuperSport Park                                          2866
# ...

# %%
final_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'season', 'city', 'date', 'team1', 'team2',
#        'toss_winner', 'toss_decision', 'result', 'dl_applied', 'winner',
#        'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue', 'umpire1',
#        'umpire2', 'umpire3', 'year'],
#       dtype='object')

# %%
final_df['dismissal_kind'].value_counts()
# Out:
# caught                   5348
# bowled                   1581
# run out                   852
# lbw                       540
# stumped                   278
# caught and bowled         211
# retired hurt               12
# hit wicket                 10
# obstructing the field       2
# Name: dismissal_kind, dtype: int64

# %%
df1=final_df[(final_df['dismissal_kind']=='caught')|(final_df['dismissal_kind']=='bowled')]

# %%
df1.groupby('batsman')['dismissal_kind'].count().sort_values(ascending=False)
# Out:
# batsman
# SK Raina        128
# V Kohli         125
# RG Sharma       125
# RV Uthappa      122
# S Dhawan        107
#                ...
# BE Hendricks      1
# P R Barman        1
# BAW Mendis        1
# GR Napier         1
# B Sumanth         1
# Name: dismissal_kind, Length: 461, dtype: int64

# %%
ipl_match[ipl_match['city'].isin(['Hyderabad','Chennai','Bangalore','Mumbai'])]

# %%
final_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'season', 'city', 'date', 'team1', 'team2',
#        'toss_winner', 'toss_decision', 'result', 'dl_applied', 'winner',
#        'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue', 'umpire1',
#        'umpire2', 'umpire3', 'year'],
#       dtype='object')

# %%
final_df['bowler'].unique()
# Out:
# array(['TS Mills', 'A Choudhary', 'YS Chahal', 'S Aravind', 'SR Watson',
#        'TM Head', 'STR Binny', 'A Nehra', 'B Kumar', 'BCJ Cutting',
#        'Rashid Khan', 'DJ Hooda', 'MC Henriques', 'Bipul Sharma',
#        'AB Dinda', 'DL Chahar', 'BA Stokes', 'Imran Tahir', 'A Zampa',
#        'R Bhatia', 'TG Southee', 'HH Pandya', 'MJ McClenaghan',
#        'JJ Bumrah', 'KH Pandya', 'KA Pollard', 'TA Boult', 'PP Chawla',
#        'SP Narine', 'CR Woakes', 'Kuldeep Yadav', 'YK Pathan', 'P Kumar',
#        'DS Kulkarni', 'MS Gony', 'S Kaushik', 'DR Smith', 'SB Jakati',
#        'Sandeep Sharma', 'MM Sharma', 'AR Patel', 'T Natarajan',
#        'MP Stoinis', 'Swapnil Singh', 'DT Christian', 'RD Chahar',
#        'Z Khan', 'CH Morris', 'PJ Cummins', 'S Nadeem', 'A Mishra',
#        'CR Brathwaite', 'B Stanlake', 'Iqbal Abdulla', 'P Negi',
#        'SK Raina', 'Tejas Baroka', 'Basil Thampi', 'SL Malinga',
#        'Harbhajan Singh', 'AS Rajpoot', 'VR Aaron', 'CJ Anderson',
# ...

# %%
df2=final_df[(final_df['batsman']=='V Kohli')&(final_df['bowler']=='JJ Bumrah')]

# %%
df2['total_runs'].sum()
# Out:
# 114

# %%
df3=final_df[final_df['dismissal_kind']=='run out']

# %%
df3['batsman'].value_counts()
# Out:
# MS Dhoni       21
# RG Sharma      17
# KD Karthik     16
# G Gambhir      15
# V Kohli        15
#                ..
# RR Bhatkal      1
# T Kohli         1
# PC Valthaty     1
# SP Fleming      1
# J Suchith       1
# Name: batsman, Length: 277, dtype: int64

# %%
final_df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'season', 'city', 'date', 'team1', 'team2',
#        'toss_winner', 'toss_decision', 'result', 'dl_applied', 'winner',
#        'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue', 'umpire1',
#        'umpire2', 'umpire3', 'year'],
#       dtype='object')

# %%
final_df['batting_team'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Mumbai Indians', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
df3=final_df[(final_df['batting_team']=='Royal Challengers Bangalore')&(final_df['bowling_team']=='Sunrisers Hyderabad')|(final_df['batting_team']=='Sunrisers Hyderabad')&(final_df['bowling_team']=='Royal Challengers Bangalore')]

# %%
df3['player_of_match'].value_counts()
# Out:
# AB de Villiers    745
# DA Warner         727
# V Kohli           341
# GH Vihari         261
# BCJ Cutting       250
# KS Williamson     249
# Yuvraj Singh      248
# S Hetmyer         246
# J Bairstow        244
# Name: player_of_match, dtype: int64
